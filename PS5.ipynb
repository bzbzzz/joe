# %%
import pandas as pd # to present the data and apply MA technique
import numpy as np # to later perform mathematical transformation
import matplotlib.pyplot as plt # make plots

# %%
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\gevor\Desktop\Econ400\data1.csv')

# %%
data.head()
# Out:
#          Date  Return  Variance
# 0  12/31/1998   41.32       NaN
# 1   1/29/1999   41.16  0.006590
# 2   2/26/1999   42.58  0.503235
# 3   3/31/1999   43.55  0.234382
# 4   4/30/1999   43.75  0.010658

# %%
import arch

# %%
r = np.array([0.5040,
-0.36114,
0.4903,
0.44255,
-0.3167,
0.67107,
-0.4475,
-0.0955,
-0.3946,
0.80145,
0.2710,
0.93019,
-0.7876,
-0.33819,
1.3177,
-0.48707,
-0.3877,
0.31739,
-0.2653,
0.70564,
-0.8033,
-0.11066,
-1.0885,
-0.03232,
0.4454,
-1.17206,
-0.7610
])
from arch import arch_model
garch11 = arch_model(r, p=1, q=1)
res = garch11.fit()
print(res.summary())
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 25.8857012297
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 25.8006502568
# Iteration:      3,   Func. Count:     25,   Neg. LLF: 25.7922910544
# Iteration:      4,   Func. Count:     31,   Neg. LLF: 25.7376757409
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 25.6534287084
# Iteration:      6,   Func. Count:     43,   Neg. LLF: 25.6509624659
# Iteration:      7,   Func. Count:     49,   Neg. LLF: 25.6507627333
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 25.6507627488
#             Iterations: 7
#             Function evaluations: 49
#             Gradient evaluations: 7
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                      -0.001
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.001
# Vol Model:                      GARCH   Log-Likelihood:               -25.6508
# Distribution:                  Normal   AIC:                           59.3015
# Method:            Maximum Likelihood   BIC:                           64.4849
#                                         No. Observations:                   27
# Date:                Wed, Nov 08 2017   Df Residuals:                       23
# Time:                        21:39:09   Df Model:                            4
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu            -0.0123      0.173 -7.070e-02      0.944 [ -0.352,  0.328]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega      6.0243e-03      0.152  3.956e-02      0.968 [ -0.292,  0.304]
# alpha[1]   2.1903e-15      0.123  1.775e-14      1.000 [ -0.242,  0.242]
# beta[1]        1.0000      0.386      2.592  9.540e-03 [  0.244,  1.756]
# ========================================================================
#
# Covariance estimator: robust

# %%
results = [0.50,
-0.36,
0.49,
0.44,
-0.32,
0.67,
-0.45,
-0.10,
-0.39,
0.80,
0.27,
0.93,
-0.79,
-0.34,
1.32,
-0.49,
-0.39,
0.32,
-0.27,
0.71,
-0.80,
-0.11,
-1.09,
-0.03,
0.45,
-1.17,
-0.76,
0.85,
0.05,
-0.28,
-0.12,
-0.78,
-0.83,
0.13,
0.76,
0.06,
-0.16,
-0.23,
0.38,
-0.71,
-0.09,
-0.78,
-0.68,
0.03,
-0.98,
0.68,
0.48,
-0.55,
-0.21,
-0.14,
0.06,
0.65,
0.45,
0.10,
0.16,
0.16,
-0.12,
0.52,
0.08,
0.50,
0.18,
0.11,
-0.18,
-0.17,
0.12,
0.18,
-0.38,
0.03,
0.10,
0.15,
0.42,
0.37,
-0.29,
0.21,
-0.20,
-0.21,
0.34,
0.01,
0.41,
-0.13,
0.08,
-0.20,
0.43,
-0.01,
0.31,
-0.01,
0.14,
0.15,
-0.39,
0.00,
0.03,
0.26,
0.30,
0.42,
0.23,
0.14,
0.23,
-0.28,
0.13,
0.56,
0.46,
-0.26,
-0.45,
0.18,
0.51,
0.23,
-0.65,
-0.10,
-0.86,
-0.43,
-0.07,
0.61,
0.18,
-1.11,
-0.16,
0.14,
-1.14,
-1.91,
-0.70,
0.09,
-0.71,
-0.83,
0.59,
0.72,
0.43,
0.45,
0.68,
0.33,
0.36,
-0.21,
0.59,
0.19,
-0.41,
0.31,
0.65,
0.17,
-0.97,
-0.59,
0.71,
-0.52,
0.92,
0.42,
-0.03,
0.77
]
print np.var(results)
# Out:
# 0.26704420814
